# %% [markdown]
# <a href="https://colab.research.google.com/github/S-mobasshira11/Machine_Learning/blob/master/Exercise_Pattern_Prediction_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Library

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd'/content/drive/MyDrive/Colab Notebooks/Dataset/Softcom Assignment 1'
# Out:
# /content/drive/MyDrive/Colab Notebooks/Dataset/Softcom Assignment 1

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('exercise_full_dataset_copy.csv').reset_index(drop=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (11,14,19,22,25,70,73,86,87,89,90,94,97,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Time series Analysis

# %%
df.rename(columns={'skewness_roll_belt.1':'skewness_pitch_belt'}, inplace=True)

# %%
df.drop('cvtd_timestamp', axis = 1, inplace=True)

# %%
print(df['raw_timestamp_part_1'].dtype)
print(df['raw_timestamp_part_2'].dtype)
# Out:
# int64
# int64

# %%
df['raw_timestamp_part_1'] = df['raw_timestamp_part_1'].astype(str)
df['raw_timestamp_part_2'] = df['raw_timestamp_part_2'].astype(str)

# %%
def concatenate_zero(val):
  if len(val) <6:
    return val + '0'
  else:
    return val

# %%
df['raw_timestamp_part_2'] = df['raw_timestamp_part_2'].apply(concatenate_zero)

# %%
print(df['raw_timestamp_part_1'].dtype)
print(df['raw_timestamp_part_2'].dtype)
# Out:
# object
# object

# %%
df["Converted Time"]= df["raw_timestamp_part_1"].str.cat(df['raw_timestamp_part_2'])

# %%
import datetime

def convert_unix_epoch(epoch_time):
  epoch_time = int(epoch_time)
  dt = datetime.datetime.fromtimestamp(epoch_time/1000000)
  return dt.strftime("%Y-%m-%d %H:%M:%S.%f %p")+'';

# %%
convert_unix_epoch(1322489729170626)
# Out:
# '2011-11-28 14:15:29.170626 PM'

# %%
df['Converted Time'] = df['Converted Time'].apply(convert_unix_epoch)

# %%
df['Converted Time'].iloc[90:100]
# Out:
# 90    2011-12-05 11:23:55.600300 AM
# 91    2011-12-05 11:23:55.620290 AM
# 92    2011-12-05 11:23:55.672360 AM
# 93    2011-12-05 11:23:55.692314 AM
# 94    2011-12-05 11:23:55.692355 AM
# 95    2011-12-05 11:23:55.732320 AM
# 96    2011-12-05 11:23:55.740299 AM
# 97    2011-12-05 11:23:55.812306 AM
# 98    2011-12-05 11:23:55.816365 AM
# 99    2011-12-05 11:23:55.908319 AM
# Name: Converted Time, dtype: object

# %%
def extract_miliseconds(val):
    val = str(val)
    return val[17:26]

# %%
df['Converted Seconds'] = df['Converted Time'].apply(extract_miliseconds)

# %%
df['Converted Seconds'].iloc[10:20]
# Out:
# 10    52.500302
# 11    52.528316
# 12    52.560359
# 13    52.576390
# 14    52.604281
# 15    52.644302
# 16    52.692324
# 17    52.732306
# 18    52.740353
# 19    52.788335
# Name: Converted Seconds, dtype: object

# %%
df1 = df.copy()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [12, 80, 90, 294, 1]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['pitch_belt'])
  s = "Pitch Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [812, 69, 89, 394, 5]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['pitch_belt'])
  s = "Pitch Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [684, 690, 465, 605, 156]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['pitch_belt'])
  s = "Pitch Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [12, 80, 90, 294, 1]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['roll_belt'])
  s = "Roll vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [812, 535, 266, 396, 821]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['roll_belt'])
  s = "Roll Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [684, 690, 465, 605, 156]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['roll_belt'])
  s = "Roll Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [12, 80, 90, 294, 1]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['yaw_belt'])
  s = "Yaw vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [812, 535, 266, 396, 821]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['yaw_belt'])
  s = "Yaw Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %%
classes = ['A', 'B', 'C', 'D', 'E']
windows = [684, 690, 465, 605, 156]

fig = plt.subplots(figsize = (25, 4))

count = 1
for i in zip(classes,windows):
  plt.subplot(1, 5, count)
  plt.plot(df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['Converted Time'],
      df1[ (df1['classe'] == i[0]) & (df1['num_window'] == i[1]) ]['yaw_belt'])
  s = "Yaw Belt vs Time For class " +  i[0]
  plt.title(s)
  count += 1

plt.show()

# %% [markdown]
# ## Data Analysis

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.set_style("whitegrid", {'axes.grid' : False})
sns.countplot(x='classe',data=df1)

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.set_style("whitegrid", {'axes.grid' : False})
sns.countplot(x="user_name", hue='classe', data=df1)

# %%
sns.boxplot(x='classe', y='avg_pitch_forearm', data=df1, showfliers=False)

# %%
sns.boxplot(x='classe', y='min_pitch_forearm', data=df1, showfliers=False)

# %%
sns.boxplot(x='classe', y='stddev_roll_belt', data=df1, showfliers=False)

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
sns.boxplot(x='classe', y='amplitude_roll_belt', data=df1, showfliers=False)

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
#sns.boxplot(x='classe', y='min_yaw_forearm', data=df1, showfliers=False)

# %%
sns.boxplot(x='classe', y='amplitude_roll_belt', data=df1, showfliers=False)

# %%
sns.boxplot(x='classe', y='max_picth_forearm', data=df1, showfliers=False)

# %%
sns.boxplot(x='classe', y='var_roll_belt', data=df1, showfliers=False)

# %%
sns.boxplot(x='classe', y='var_accel_forearm', data=df1, showfliers=False)

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_excel('exercise_full_dataset.xlsx').reset_index(drop=True)

# %%
len(df)
# Out:
# 39242

# %%
df.head(3)
# Out:
#   user_name  raw_timestamp_part_1  raw_timestamp_part_2    cvtd_timestamp  \
# 0    eurico          1.322490e+09               34670.0  28/11/2011 14:15
# 1    eurico          1.322490e+09               62641.0  28/11/2011 14:15
# 2    eurico          1.322490e+09               70653.0  28/11/2011 14:15
#
#   new_window  num_window  roll_belt  pitch_belt  yaw_belt  total_accel_belt  \
# 0         no         1.0       3.70        41.6     -82.8               3.0
# 1         no         1.0       3.66        42.8     -82.5               2.0
# 2         no         1.0       3.58        43.7     -82.3               1.0
#
#    ...  gyros_forearm_x  gyros_forearm_y  gyros_forearm_z  accel_forearm_x  \
# 0  ...            -0.05            -0.37            -0.43           -170.0
# 1  ...            -0.06            -0.37            -0.59           -178.0
# 2  ...            -0.05            -0.27            -0.72           -182.0
#
#    accel_forearm_y  accel_forearm_z  magnet_forearm_x  magnet_forearm_y  \
# 0            155.0            184.0           -1160.0            1400.0
# 1            164.0            182.0           -1150.0            1410.0
# 2            172.0            185.0           -1130.0            1400.0
#
#    magnet_forearm_z  classe
# 0            -876.0       E
# 1            -871.0       E
# 2            -863.0       E
#
# [3 rows x 159 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39242 entries, 0 to 39241
# Columns: 159 entries, user_name to classe
# dtypes: float64(155), object(4)
# memory usage: 47.6+ MB

# %%
df.describe()
# Out:
#        raw_timestamp_part_1  raw_timestamp_part_2    num_window     roll_belt  \
# count          3.924200e+04          39242.000000  39242.000000  39242.000000
# mean           1.322827e+09         500708.627465    432.322282     64.928120
# std            2.040334e+05         288682.935235    247.966725     62.672987
# min            1.322490e+09            280.000000      1.000000    -28.900000
# 25%            1.322673e+09         252299.500000    222.000000      1.100000
# 50%            1.322833e+09         498781.500000    428.000000    114.000000
# 75%            1.323084e+09         752287.750000    647.000000    123.000000
# max            1.323095e+09         999091.000000    864.000000    162.000000
#
#          pitch_belt      yaw_belt  total_accel_belt  kurtosis_roll_belt  \
# count  39242.000000  39242.000000      39242.000000          807.000000
# mean       0.423624    -10.827983         11.378982           -0.181088
# std       22.400539     94.982455          7.732219            3.739289
# min      -56.200000   -180.000000          0.000000           -3.333333
# 25%        1.830000    -88.200000          3.000000           -1.346611
# 50%        5.320000    -11.900000         17.000000           -0.907946
# 75%       15.500000     12.500000         18.000000           -0.282445
# max       60.300000    180.000000         30.000000           50.979819
#
#        kurtosis_picth_belt  kurtosis_yaw_belt  ...  var_yaw_forearm  \
# count           767.000000                0.0  ...       839.000000
# mean              4.533324                NaN  ...      4702.779079
# std              11.328069                NaN  ...      7224.874200
# min              -2.210526                NaN  ...         0.000000
# 25%              -1.079763                NaN  ...         0.251195
# 50%              -0.021887                NaN  ...       606.510220
# 75%               4.148419                NaN  ...      7648.713645
# max              71.000000                NaN  ...     39009.333330
#
#        gyros_forearm_x  gyros_forearm_y  gyros_forearm_z  accel_forearm_x  \
# count     39242.000000     39242.000000     39242.000000     39242.000000
# mean          0.146381         0.095838         0.147643       -63.954814
# std           1.827178         3.735124         1.337704       180.940999
# min        -339.000000        -7.030000       -52.000000      -498.000000
# 25%          -0.220000        -1.450000        -0.180000      -181.000000
# 50%           0.050000         0.030000         0.080000       -58.000000
# 75%           0.560000         1.650000         0.490000        74.000000
# max           4.770000       516.000000       231.000000       479.000000
#
#        accel_forearm_y  accel_forearm_z  magnet_forearm_x  magnet_forearm_y  \
# count     39242.000000     39242.000000      39242.000000      39242.000000
# mean        162.981005       -55.494751       -316.640326        379.762296
# std         199.580505       137.692832        345.893844        507.055260
# min        -690.000000      -458.000000      -1280.000000       -906.000000
# 25%          53.000000      -181.000000       -620.000000          8.000000
# 50%         200.000000       -40.500000       -385.000000        588.000000
# 75%         312.000000        25.000000        -77.000000        736.000000
# max         923.000000       291.000000        672.000000       1480.000000
#
#        magnet_forearm_z
# count      39242.000000
# mean         395.010309
# std          368.098954
# min         -973.000000
# 25%          200.000000
# 50%          512.000000
# 75%          652.000000
# max         1090.000000
#
# [8 rows x 155 columns]

# %%
df.classe.value_counts()
# Out:
# A    11159
# B     7593
# E     7214
# C     6844
# D     6432
# Name: classe, dtype: int64

# %%
df.rename(columns={'skewness_roll_belt.1':'skewness_pitch_belt'}, inplace=True)

# %%
print(df['kurtosis_roll_belt'].nunique())
print(df['num_window'].nunique())
print('Number of Empty Values : ', df['kurtosis_roll_belt'].isnull().sum(axis = 0))
print('Number of Empty Values : ', df['num_window'].isnull().sum(axis = 0))
# Out:
# 791
# 861
# Number of Empty Values :  38435
# Number of Empty Values :  0

# %%
print('Column Name', '  No of Missing Values')
for i in zip(df.columns, df.isna().sum()):
  print(i[0], '\t\t', i[1])
# Out:
# Column Name   No of Missing Values
# user_name 		 0
# raw_timestamp_part_1 		 0
# raw_timestamp_part_2 		 0
# cvtd_timestamp 		 0
# new_window 		 0
# num_window 		 0
# roll_belt 		 0
# pitch_belt 		 0
# yaw_belt 		 0
# total_accel_belt 		 0
# kurtosis_roll_belt 		 38435
# kurtosis_picth_belt 		 38475
# kurtosis_yaw_belt 		 39242
# skewness_roll_belt 		 38434
# skewness_pitch_belt 		 38475
# skewness_yaw_belt 		 39242
# max_roll_belt 		 38403
# max_picth_belt 		 38403
# max_yaw_belt 		 38435
# min_roll_belt 		 38403
# min_pitch_belt 		 38403
# min_yaw_belt 		 38435
# amplitude_roll_belt 		 38403
# amplitude_pitch_belt 		 38403
# amplitude_yaw_belt 		 38435
# var_total_accel_belt 		 38403
# avg_roll_belt 		 38402
# stddev_roll_belt 		 38403
# var_roll_belt 		 38403
# avg_pitch_belt 		 38403
# stddev_pitch_belt 		 38403
# var_pitch_belt 		 38403
# avg_yaw_belt 		 38403
# stddev_yaw_belt 		 38403
# var_yaw_belt 		 38403
# gyros_belt_x 		 0
# gyros_belt_y 		 0
# gyros_belt_z 		 0
# accel_belt_x 		 0
# accel_belt_y 		 0
# accel_belt_z 		 0
# magnet_belt_x 		 0
# magnet_belt_y 		 0
# magnet_belt_z 		 0
# roll_arm 		 0
# pitch_arm 		 0
# yaw_arm 		 0
# total_accel_arm 		 0
# var_accel_arm 		 38403
# avg_roll_arm 		 38403
# stddev_roll_arm 		 38403
# var_roll_arm 		 38403
# avg_pitch_arm 		 38403
# stddev_pitch_arm 		 38403
# var_pitch_arm 		 38403
# avg_yaw_arm 		 38403
# stddev_yaw_arm 		 38403
# var_yaw_arm 		 38403
# gyros_arm_x 		 0
# gyros_arm_y 		 0
# gyros_arm_z 		 0
# accel_arm_x 		 0
# accel_arm_y 		 0
# accel_arm_z 		 0
# magnet_arm_x 		 0
# magnet_arm_y 		 0
# magnet_arm_z 		 0
# kurtosis_roll_arm 		 38548
# kurtosis_picth_arm 		 38554
# kurtosis_yaw_arm 		 38431
# skewness_roll_arm 		 38547
# skewness_pitch_arm 		 38554
# skewness_yaw_arm 		 38431
# max_roll_arm 		 38403
# max_picth_arm 		 38403
# max_yaw_arm 		 38403
# min_roll_arm 		 38403
# min_pitch_arm 		 38403
# min_yaw_arm 		 38403
# amplitude_roll_arm 		 38403
# amplitude_pitch_arm 		 38403
# amplitude_yaw_arm 		 38403
# roll_dumbbell 		 1
# pitch_dumbbell 		 0
# yaw_dumbbell 		 0
# kurtosis_roll_dumbbell 		 38412
# kurtosis_picth_dumbbell 		 38407
# kurtosis_yaw_dumbbell 		 39242
# skewness_roll_dumbbell 		 38411
# skewness_pitch_dumbbell 		 38406
# skewness_yaw_dumbbell 		 39242
# max_roll_dumbbell 		 38403
# max_picth_dumbbell 		 38403
# max_yaw_dumbbell 		 38412
# min_roll_dumbbell 		 38403
# min_pitch_dumbbell 		 38403
# min_yaw_dumbbell 		 38412
# amplitude_roll_dumbbell 		 38403
# amplitude_pitch_dumbbell 		 38403
# amplitude_yaw_dumbbell 		 38412
# total_accel_dumbbell 		 0
# var_accel_dumbbell 		 38403
# avg_roll_dumbbell 		 38403
# stddev_roll_dumbbell 		 38403
# var_roll_dumbbell 		 38403
# avg_pitch_dumbbell 		 38403
# stddev_pitch_dumbbell 		 38403
# var_pitch_dumbbell 		 38403
# avg_yaw_dumbbell 		 38403
# stddev_yaw_dumbbell 		 38403
# var_yaw_dumbbell 		 38403
# gyros_dumbbell_x 		 0
# gyros_dumbbell_y 		 0
# gyros_dumbbell_z 		 0
# accel_dumbbell_x 		 0
# accel_dumbbell_y 		 0
# accel_dumbbell_z 		 0
# magnet_dumbbell_x 		 0
# magnet_dumbbell_y 		 0
# magnet_dumbbell_z 		 0
# roll_forearm 		 0
# pitch_forearm 		 0
# yaw_forearm 		 0
# kurtosis_roll_forearm 		 38581
# kurtosis_picth_forearm 		 38584
# kurtosis_yaw_forearm 		 39242
# skewness_roll_forearm 		 38580
# skewness_pitch_forearm 		 38584
# skewness_yaw_forearm 		 39242
# max_roll_forearm 		 38403
# max_picth_forearm 		 38403
# max_yaw_forearm 		 38581
# min_roll_forearm 		 38403
# min_pitch_forearm 		 38403
# min_yaw_forearm 		 38581
# amplitude_roll_forearm 		 38403
# amplitude_pitch_forearm 		 38403
# amplitude_yaw_forearm 		 38581
# total_accel_forearm 		 0
# var_accel_forearm 		 38403
# avg_roll_forearm 		 38403
# stddev_roll_forearm 		 38403
# var_roll_forearm 		 38403
# avg_pitch_forearm 		 38403
# stddev_pitch_forearm 		 38403
# var_pitch_forearm 		 38403
# avg_yaw_forearm 		 38403
# stddev_yaw_forearm 		 38403
# var_yaw_forearm 		 38403
# gyros_forearm_x 		 0
# gyros_forearm_y 		 0
# gyros_forearm_z 		 0
# accel_forearm_x 		 0
# accel_forearm_y 		 0
# accel_forearm_z 		 0
# magnet_forearm_x 		 0
# magnet_forearm_y 		 0
# magnet_forearm_z 		 0
# classe 		 0

# %%
len(df)
# Out:
# 39242

# %%
empty_max_cols = ['max_roll_belt', 'max_picth_belt',  'max_yaw_belt',
            'max_roll_arm', 'max_picth_arm', 'max_yaw_arm',
            'max_roll_dumbbell', 'max_picth_dumbbell', 'max_yaw_dumbbell',
            'max_roll_forearm', 'max_picth_forearm', 'max_yaw_forearm'
            ]

empty_min_cols = ['min_roll_belt', 'min_pitch_belt',  'min_yaw_belt',
            'min_roll_arm', 'min_pitch_arm', 'min_yaw_arm',
            'min_roll_dumbbell', 'min_pitch_dumbbell', 'min_yaw_dumbbell',
            'min_roll_forearm', 'min_pitch_forearm', 'min_yaw_forearm'
            ]

empty_avg_cols = ['avg_roll_belt', 'avg_pitch_belt',  'avg_yaw_belt',
            'avg_roll_arm', 'avg_pitch_arm', 'avg_yaw_arm',
            'avg_roll_dumbbell', 'avg_pitch_dumbbell', 'avg_yaw_dumbbell',
            'avg_roll_forearm', 'avg_pitch_forearm', 'avg_yaw_forearm'
            ]

empty_var_cols = ['var_roll_belt', 'var_pitch_belt',  'var_yaw_belt',
            'var_roll_arm', 'var_pitch_arm', 'var_yaw_arm',
            'var_roll_dumbbell', 'var_pitch_dumbbell', 'var_yaw_dumbbell',
            'var_roll_forearm', 'var_pitch_forearm', 'var_yaw_forearm'
            ]

empty_std_cols = ['stddev_roll_belt', 'stddev_pitch_belt',  'stddev_yaw_belt',
            'stddev_roll_arm', 'stddev_pitch_arm', 'stddev_yaw_arm',
            'stddev_roll_dumbbell', 'stddev_pitch_dumbbell', 'stddev_yaw_dumbbell',
            'stddev_roll_forearm', 'stddev_pitch_forearm', 'stddev_yaw_forearm'
            ]

empty_kurtosis_cols = ['kurtosis_roll_belt', 'kurtosis_pitch_belt',  'kurtosis_yaw_belt',
            'kurtosis_roll_arm', 'kurtosis_pitch_arm', 'kurtosis_yaw_arm',
            'kurtosis_roll_dumbbell', 'kurtosis_pitch_dumbbell', 'kurtosis_yaw_dumbbell',
            'kurtosis_roll_forearm', 'kurtosis_pitch_forearm', 'kurtosis_yaw_forearm'
            ]


empty_kurtosis_cols = ['kurtosis_roll_belt', 'kurtosis_picth_belt',  'kurtosis_yaw_belt',
            'kurtosis_roll_arm', 'kurtosis_picth_arm', 'kurtosis_yaw_arm',
            'kurtosis_roll_dumbbell', 'kurtosis_picth_dumbbell', 'kurtosis_yaw_dumbbell',
            'kurtosis_roll_forearm', 'kurtosis_picth_forearm', 'kurtosis_yaw_forearm'
            ]

empty_skew_cols = ['skewness_roll_belt', 'skewness_pitch_belt',  'skewness_yaw_belt',
            'skewness_roll_arm', 'skewness_pitch_arm', 'skewness_yaw_arm',
            'skewness_roll_dumbbell', 'skewness_pitch_dumbbell', 'skewness_yaw_dumbbell',
            'skewness_roll_forearm', 'skewness_pitch_forearm', 'skewness_yaw_forearm'
            ]

empty_amplitude_cols = ['amplitude_roll_belt', 'amplitude_pitch_belt',  'amplitude_yaw_belt',
            'amplitude_roll_arm', 'amplitude_pitch_arm', 'amplitude_yaw_arm',
            'amplitude_roll_dumbbell', 'amplitude_pitch_dumbbell', 'amplitude_yaw_dumbbell',
            'amplitude_roll_forearm', 'amplitude_pitch_forearm', 'amplitude_yaw_forearm'
            ]

empty_acceleration_cols = ['var_total_accel_belt', 'var_accel_arm',  'var_accel_dumbbell',
                           'var_accel_forearm']

attributes = [
              'roll_belt','pitch_belt','yaw_belt',
              'roll_arm', 'pitch_arm', 'yaw_arm',
              'roll_dumbbell', 'pitch_dumbbell', 'yaw_dumbbell',
              'roll_forearm', 'pitch_forearm', 'yaw_forearm',
              ]

attributes2 = ['total_accel_belt',  'total_accel_arm', 'total_accel_dumbbell',
               'total_accel_forearm']

# %%
df2 = df.copy()

# %%
len(df2)
# Out:
# 39242

# %%
for j in zip(empty_max_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    max_val = df2[(df2['num_window'] == i)][j[1]].max()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = max_val

# %%
for j in zip(empty_min_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    min_val = df2[(df2['num_window'] == i)][j[1]].min()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = min_val

# %%
for j in zip(empty_avg_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    mean_val = df2[(df2['num_window'] == i)][j[1]].mean()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = mean_val

# %%
for j in zip(empty_var_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    var_val = df2[(df2['num_window'] == i)][j[1]].var()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = var_val

# %%
for j in zip(empty_std_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    std_val = df2[(df2['num_window'] == i)][j[1]].std()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = std_val

# %%
for j in zip(empty_kurtosis_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    std_val = df2[(df2['num_window'] == i)][j[1]].kurtosis()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = std_val

# %%
for j in zip(empty_skew_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    std_val = df2[(df2['num_window'] == i)][j[1]].skew()
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = std_val

# %%
for j in zip(empty_amplitude_cols, attributes):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    val1 = df2[(df2['num_window'] == i)][j[1]].max()
    val2 = df2[(df2['num_window'] == i)][j[1]].min()
    val = abs(val1 - val2)
    df2.loc[ (df2['num_window'] == i) ,j[0] ] = val

# %%
for j in zip(empty_acceleration_cols, attributes2):
  for i in df2[df2[j[0]].isna()]['num_window'].unique():
    val = df2[(df2['num_window'] == i)][j[1]].var()
    df2.loc[(df2['num_window'] == i),j[0]] = val

# %%
print(len(df2))
# Out:
# 39242

# %%
print('Column Name', '  No of Missing Values\n')
for i in zip(df2.columns, df2.isna().sum()):
  print(i[0], '\t\t', i[1])
# Out:
# Column Name   No of Missing Values
#
# user_name 		 0
# raw_timestamp_part_1 		 0
# raw_timestamp_part_2 		 0
# cvtd_timestamp 		 0
# new_window 		 0
# num_window 		 0
# roll_belt 		 0
# pitch_belt 		 0
# yaw_belt 		 0
# total_accel_belt 		 0
# kurtosis_roll_belt 		 12
# kurtosis_picth_belt 		 12
# kurtosis_yaw_belt 		 12
# skewness_roll_belt 		 6
# skewness_pitch_belt 		 6
# skewness_yaw_belt 		 6
# max_roll_belt 		 0
# max_picth_belt 		 0
# max_yaw_belt 		 0
# min_roll_belt 		 0
# min_pitch_belt 		 0
# min_yaw_belt 		 0
# amplitude_roll_belt 		 0
# amplitude_pitch_belt 		 0
# amplitude_yaw_belt 		 0
# var_total_accel_belt 		 2
# avg_roll_belt 		 0
# stddev_roll_belt 		 2
# var_roll_belt 		 2
# avg_pitch_belt 		 0
# stddev_pitch_belt 		 2
# var_pitch_belt 		 2
# avg_yaw_belt 		 0
# stddev_yaw_belt 		 2
# var_yaw_belt 		 2
# gyros_belt_x 		 0
# gyros_belt_y 		 0
# gyros_belt_z 		 0
# accel_belt_x 		 0
# accel_belt_y 		 0
# accel_belt_z 		 0
# magnet_belt_x 		 0
# magnet_belt_y 		 0
# magnet_belt_z 		 0
# roll_arm 		 0
# pitch_arm 		 0
# yaw_arm 		 0
# total_accel_arm 		 0
# var_accel_arm 		 2
# avg_roll_arm 		 0
# stddev_roll_arm 		 2
# var_roll_arm 		 2
# avg_pitch_arm 		 0
# stddev_pitch_arm 		 2
# var_pitch_arm 		 2
# avg_yaw_arm 		 0
# stddev_yaw_arm 		 2
# var_yaw_arm 		 2
# gyros_arm_x 		 0
# gyros_arm_y 		 0
# gyros_arm_z 		 0
# accel_arm_x 		 0
# accel_arm_y 		 0
# accel_arm_z 		 0
# magnet_arm_x 		 0
# magnet_arm_y 		 0
# magnet_arm_z 		 0
# kurtosis_roll_arm 		 12
# kurtosis_picth_arm 		 12
# kurtosis_yaw_arm 		 12
# skewness_roll_arm 		 6
# skewness_pitch_arm 		 6
# skewness_yaw_arm 		 6
# max_roll_arm 		 0
# max_picth_arm 		 0
# max_yaw_arm 		 0
# min_roll_arm 		 0
# min_pitch_arm 		 0
# min_yaw_arm 		 0
# amplitude_roll_arm 		 0
# amplitude_pitch_arm 		 0
# amplitude_yaw_arm 		 0
# roll_dumbbell 		 1
# pitch_dumbbell 		 0
# yaw_dumbbell 		 0
# kurtosis_roll_dumbbell 		 12
# kurtosis_picth_dumbbell 		 12
# kurtosis_yaw_dumbbell 		 12
# skewness_roll_dumbbell 		 6
# skewness_pitch_dumbbell 		 6
# skewness_yaw_dumbbell 		 6
# max_roll_dumbbell 		 0
# max_picth_dumbbell 		 0
# max_yaw_dumbbell 		 0
# min_roll_dumbbell 		 0
# min_pitch_dumbbell 		 0
# min_yaw_dumbbell 		 0
# amplitude_roll_dumbbell 		 0
# amplitude_pitch_dumbbell 		 0
# amplitude_yaw_dumbbell 		 0
# total_accel_dumbbell 		 0
# var_accel_dumbbell 		 2
# avg_roll_dumbbell 		 0
# stddev_roll_dumbbell 		 2
# var_roll_dumbbell 		 2
# avg_pitch_dumbbell 		 0
# stddev_pitch_dumbbell 		 2
# var_pitch_dumbbell 		 2
# avg_yaw_dumbbell 		 0
# stddev_yaw_dumbbell 		 2
# var_yaw_dumbbell 		 2
# gyros_dumbbell_x 		 0
# gyros_dumbbell_y 		 0
# gyros_dumbbell_z 		 0
# accel_dumbbell_x 		 0
# accel_dumbbell_y 		 0
# accel_dumbbell_z 		 0
# magnet_dumbbell_x 		 0
# magnet_dumbbell_y 		 0
# magnet_dumbbell_z 		 0
# roll_forearm 		 0
# pitch_forearm 		 0
# yaw_forearm 		 0
# kurtosis_roll_forearm 		 12
# kurtosis_picth_forearm 		 12
# kurtosis_yaw_forearm 		 12
# skewness_roll_forearm 		 6
# skewness_pitch_forearm 		 6
# skewness_yaw_forearm 		 6
# max_roll_forearm 		 0
# max_picth_forearm 		 0
# max_yaw_forearm 		 0
# min_roll_forearm 		 0
# min_pitch_forearm 		 0
# min_yaw_forearm 		 0
# amplitude_roll_forearm 		 0
# amplitude_pitch_forearm 		 0
# amplitude_yaw_forearm 		 0
# total_accel_forearm 		 0
# var_accel_forearm 		 2
# avg_roll_forearm 		 0
# stddev_roll_forearm 		 2
# var_roll_forearm 		 2
# avg_pitch_forearm 		 0
# stddev_pitch_forearm 		 2
# var_pitch_forearm 		 2
# avg_yaw_forearm 		 0
# stddev_yaw_forearm 		 2
# var_yaw_forearm 		 2
# gyros_forearm_x 		 0
# gyros_forearm_y 		 0
# gyros_forearm_z 		 0
# accel_forearm_x 		 0
# accel_forearm_y 		 0
# accel_forearm_z 		 0
# magnet_forearm_x 		 0
# magnet_forearm_y 		 0
# magnet_forearm_z 		 0
# classe 		 0

# %%
df2.dropna(axis=0, inplace=True)

# %%
print(len(df2))
# Out:
# 39229

# %%
df2.to_csv('Preprocessed_Exercise_PR.csv')

# %% [markdown]
# ## Pearson Correlation

# %%
load = pd.read_csv('Preprocessed_Exercise_PR.csv')

# %%
df1 = load.copy()

# %%
for i in df1['num_window'].unique():
    df1.drop(df1.loc[(df1['new_window']=='no') & (df1['num_window']==i)].index, inplace=True)

# %%
len(df1)
# Out:
# 838

# %%
def impute_classe(x):
  if x == 'A':
    return 4
  elif x =='B':
    return 3
  elif x=='C':
    return 2
  elif x=='D':
    return 1
  elif x=='E':
    return 0

# %%
df1['classe'] = df1['classe'].apply(impute_classe)

# %%
df1.classe.value_counts()
# Out:
# 4    239
# 3    161
# 0    156
# 2    145
# 1    137
# Name: classe, dtype: int64

# %%
del_cols = ['Unnamed: 0' ,'user_name' ,'raw_timestamp_part_1' ,'raw_timestamp_part_2' ,'cvtd_timestamp' ,'new_window' ,'num_window',
            'roll_belt' ,'pitch_belt' ,'yaw_belt', 'roll_arm' ,'pitch_arm' ,'yaw_arm', 'roll_dumbbell' ,'pitch_dumbbell' ,'yaw_dumbbell',
            'roll_forearm' ,'pitch_forearm' ,'yaw_forearm', 'gyros_belt_x',
            'gyros_belt_x', 'gyros_belt_y', 'gyros_belt_z', 'accel_belt_x', 'accel_belt_y', 'accel_belt_z', 'magnet_belt_x',
            'magnet_belt_y', 'magnet_belt_z', 'gyros_arm_x', 'gyros_arm_y', 'gyros_arm_z', 'accel_arm_x', 'accel_arm_y', 'accel_arm_z',
            'magnet_arm_x', 'magnet_arm_y', 'magnet_arm_z', 'gyros_dumbbell_x', 'gyros_dumbbell_y', 'gyros_dumbbell_z',
            'accel_dumbbell_x', 'accel_dumbbell_y', 'accel_dumbbell_z', 'magnet_dumbbell_x', 'magnet_dumbbell_y', 'magnet_dumbbell_z',
            'gyros_forearm_x', 'gyros_forearm_y', 'gyros_forearm_z', 'accel_forearm_x', 'accel_forearm_y', 'accel_forearm_z', 'magnet_forearm_x',
            'magnet_forearm_y', 'magnet_forearm_z']

# %%
df1.drop(del_cols,axis=1, inplace=True)

# %%
len(df1.columns)
# Out:
# 105

# %%
sns.set(rc={'figure.figsize':(15,9)})
lst = list(df1.columns[0:26])
lst.append('classe')
belt_corr = df1[lst].corr()
sns.heatmap(belt_corr)

# %%
sns.set(rc={'figure.figsize':(15,9)})
lst = list(df1.columns[26:52])
lst.append('classe')
arm_corr = df1[lst].corr()
sns.heatmap(arm_corr)

# %%
sns.set(rc={'figure.figsize':(15,9)})
lst = list(df1.columns[52:78])
lst.append('classe')
dumbell_corr = df1[lst].corr()
sns.heatmap(dumbell_corr)

# %%
sns.set(rc={'figure.figsize':(15,9)})
lst = list(df1.columns[78:104])
lst.append('classe')
forearm_corr = df1[lst].corr()
sns.heatmap(forearm_corr)

# %%
corr = [belt_corr, arm_corr, dumbell_corr, forearm_corr]

# %%
for i in corr:
    print(i[(i['classe'] < -0.05) ]['classe'])
    print()
    print(i[(i['classe'] > 0.05) ]['classe'])
# Out:
# total_accel_belt       -0.075354
# max_roll_belt          -0.080729
# amplitude_roll_belt    -0.517679
# amplitude_pitch_belt   -0.391736
# amplitude_yaw_belt     -0.073915
# var_total_accel_belt   -0.430095
# avg_roll_belt          -0.052178
# stddev_roll_belt       -0.507899
# var_roll_belt          -0.387454
# stddev_pitch_belt      -0.393716
# var_pitch_belt         -0.181123
# stddev_yaw_belt        -0.066859
# Name: classe, dtype: float64
#
# kurtosis_yaw_belt    0.050232
# classe               1.000000
# Name: classe, dtype: float64
# var_accel_arm         -0.246523
# avg_roll_arm          -0.086315
# stddev_pitch_arm      -0.086839
# avg_yaw_arm           -0.060786
# stddev_yaw_arm        -0.090528
# max_roll_arm          -0.073429
# max_yaw_arm           -0.107966
# min_roll_arm          -0.091099
# amplitude_pitch_arm   -0.080953
# amplitude_yaw_arm     -0.108984
# Name: classe, dtype: float64
#
# total_accel_arm     0.114368
# var_roll_arm        0.071636
# avg_pitch_arm       0.202765
# kurtosis_yaw_arm    0.076788
# max_picth_arm       0.166459
# min_pitch_arm       0.226070
# classe              1.000000
# Name: classe, dtype: float64
# kurtosis_roll_dumbbell    -0.080291
# kurtosis_picth_dumbbell   -0.083781
# kurtosis_yaw_dumbbell     -0.084869
# max_roll_dumbbell         -0.070443
# max_picth_dumbbell        -0.075858
# min_pitch_dumbbell        -0.075313
# var_accel_dumbbell        -0.073813
# avg_roll_dumbbell         -0.051292
# avg_pitch_dumbbell        -0.102220
# Name: classe, dtype: float64
#
# skewness_yaw_dumbbell    0.095056
# classe                   1.000000
# Name: classe, dtype: float64
# max_roll_forearm         -0.178282
# max_picth_forearm        -0.292441
# max_yaw_forearm          -0.106097
# min_pitch_forearm        -0.439127
# amplitude_roll_forearm   -0.179390
# amplitude_yaw_forearm    -0.193341
# total_accel_forearm      -0.162813
# var_accel_forearm        -0.214494
# stddev_roll_forearm      -0.182815
# var_roll_forearm         -0.173702
# avg_pitch_forearm        -0.378978
# stddev_yaw_forearm       -0.205052
# var_yaw_forearm          -0.188299
# Name: classe, dtype: float64
#
# kurtosis_picth_forearm    0.067629
# kurtosis_yaw_forearm      0.082697
# min_roll_forearm          0.094901
# min_yaw_forearm           0.166461
# var_pitch_forearm         0.122144
# classe                    1.000000
# Name: classe, dtype: float64

# %%
high_corr = []
for i in corr:
    high_corr.extend(list((i[(i['classe'] < -0.05) ]['classe']).index))

for i in corr:
    high_corr.extend(list((i[(i['classe'] > 0.05) ]['classe']).index))

# %%
high_corr = [i for i in high_corr if i != 'classe']
high_corr.append('classe')

# %%
len(high_corr)
# Out:
# 58

# %%
df2 = df1.copy()

# %%
df2 = df2[high_corr]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
from sklearn.model_selection import train_test_split
X = df2.drop(['classe'], axis=1)
y = df2['classe']

X = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split( X, y, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB


from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
models = {
    DecisionTreeClassifier() : "Decision Tree Classifier",
    KNeighborsClassifier(n_neighbors=3):  "KNN",
    RandomForestClassifier(n_estimators=100): "RandomForestClassifier",
    SVC() : "SVC",
    GaussianNB() : "Gaussian Naive Bayes",
}

# %%
for model in models.keys():
    model.fit(X_train, y_train)

for model, name in models.items():
    predictions = model.predict(X_test)
    print(name , ' : ',  accuracy_score(y_test, predictions))
    print(classification_report(y_test,predictions))
# Out:
# Decision Tree Classifier  :  0.6619047619047619
#               precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68        34
#            1       0.39      0.62      0.48        21
#            2       0.73      0.68      0.71        44
#            3       0.72      0.61      0.66        51
#            4       0.73      0.68      0.71        60
#
#     accuracy                           0.66       210
#    macro avg       0.65      0.66      0.65       210
# weighted avg       0.68      0.66      0.67       210
#
# KNN  :  0.6761904761904762
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77        34
#            1       0.43      1.00      0.60        21
#            2       0.65      0.64      0.64        44
#            3       0.88      0.43      0.58        51
#            4       0.77      0.73      0.75        60
#
#     accuracy                           0.68       210
#    macro avg       0.70      0.72      0.67       210
# weighted avg       0.73      0.68      0.68       210
#
# RandomForestClassifier  :  0.8571428571428571
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93        34
#            1       0.63      0.81      0.71        21
#            2       0.88      0.84      0.86        44
#            3       0.89      0.78      0.83        51
#            4       0.87      0.92      0.89        60
#
#     accuracy                           0.86       210
#    macro avg       0.84      0.85      0.84       210
# weighted avg       0.86      0.86      0.86       210
#
# SVC  :  0.7238095238095238
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87        34
#            1       0.50      0.76      0.60        21
#            2       0.65      0.73      0.69        44
#            3       0.82      0.63      0.71        51
#            4       0.73      0.73      0.73        60
#
#     accuracy                           0.72       210
#    macro avg       0.73      0.73      0.72       210
# weighted avg       0.75      0.72      0.73       210
#
# Gaussian Naive Bayes  :  0.5619047619047619
#               precision    recall  f1-score   support
#
#            0       0.95      0.56      0.70        34
#            1       0.25      0.14      0.18        21
#            2       0.41      0.89      0.56        44
#            3       0.69      0.49      0.57        51
#            4       0.68      0.53      0.60        60
#
#     accuracy                           0.56       210
#    macro avg       0.60      0.52      0.52       210
# weighted avg       0.63      0.56      0.56       210

# %% [markdown]
# ## F-Test

# %%
X = df1.drop(['classe'], axis=1)
y = df1['classe']
X = StandardScaler().fit_transform(X)
X = pd.DataFrame(X,columns = df1.drop(['classe'],axis=1).columns)
X_train, X_test, y_train, y_test = train_test_split( X, y, random_state=42)

# %%
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(f_classif, k=58)
selector.fit(X_train, y_train)
# Out:
# SelectKBest(k=58)

# %%
cols = selector.get_support(indices=True)
cols
# Out:
# array([ 13,  14,  16,  18,  19,  21,  22,  26,  27,  28,  29,  31,  32,
#         33,  35,  43,  44,  45,  46,  47,  49,  50,  51,  52,  53,  54,
#         56,  57,  58,  59,  61,  62,  64,  65,  68,  69,  70,  71,  72,
#         73,  76,  84,  85,  86,  87,  88,  89,  90,  92,  93,  94,  95,
#         96,  97,  98, 101, 102, 103])

# %%
X_train = X_train.iloc[:,cols]
X_test = X_test.iloc[:,cols]

# %%
X_train.shape
# Out:
# (628, 58)

# %%
for model in models.keys():
    model.fit(X_train, y_train)

for model, name in models.items():
    predictions = model.predict(X_test)
    print(name , ' : ',  accuracy_score(y_test, predictions))
    print(classification_report(y_test,predictions))
# Out:
# Decision Tree Classifier  :  0.6428571428571429
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79        34
#            1       0.35      0.43      0.38        21
#            2       0.65      0.70      0.67        44
#            3       0.71      0.59      0.65        51
#            4       0.63      0.65      0.64        60
#
#     accuracy                           0.64       210
#    macro avg       0.63      0.63      0.63       210
# weighted avg       0.65      0.64      0.65       210
#
# KNN  :  0.7047619047619048
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.82        34
#            1       0.44      1.00      0.61        21
#            2       0.66      0.66      0.66        44
#            3       0.89      0.49      0.63        51
#            4       0.79      0.77      0.78        60
#
#     accuracy                           0.70       210
#    macro avg       0.73      0.74      0.70       210
# weighted avg       0.76      0.70      0.71       210
#
# RandomForestClassifier  :  0.8238095238095238
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88        34
#            1       0.70      0.90      0.79        21
#            2       0.85      0.80      0.82        44
#            3       0.84      0.71      0.77        51
#            4       0.81      0.90      0.85        60
#
#     accuracy                           0.82       210
#    macro avg       0.82      0.83      0.82       210
# weighted avg       0.83      0.82      0.82       210
#
# SVC  :  0.7428571428571429
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86        34
#            1       0.55      0.86      0.67        21
#            2       0.67      0.70      0.69        44
#            3       0.89      0.65      0.75        51
#            4       0.73      0.77      0.75        60
#
#     accuracy                           0.74       210
#    macro avg       0.75      0.76      0.74       210
# weighted avg       0.77      0.74      0.75       210
#
# Gaussian Naive Bayes  :  0.5761904761904761
#               precision    recall  f1-score   support
#
#            0       0.95      0.62      0.75        34
#            1       0.22      0.10      0.13        21
#            2       0.45      0.80      0.58        44
#            3       0.56      0.67      0.61        51
#            4       0.71      0.48      0.57        60
#
#     accuracy                           0.58       210
#    macro avg       0.58      0.53      0.53       210
# weighted avg       0.61      0.58      0.57       210

# %% [markdown]
# ## AUC ROC

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import metrics

clf = OneVsRestClassifier(RandomForestClassifier())
clf.fit(X_train, y_train)

pred_prob = clf.predict_proba(X_test)

fpr = {}
tpr = {}
thresh ={}
roc_auc = {}

n_class = 5

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pred_prob[:,i], pos_label=i)
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

plt.figure(figsize=(12,8))
plt.plot(fpr[0], tpr[0], linestyle='solid',color='magenta', label='A vs Rest (AUC = %0.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1], linestyle='solid',color='green', label='B vs Rest (AUC = %0.2f)' % roc_auc[1])
plt.plot(fpr[2], tpr[2], linestyle='solid',color='orange', label='C Severe vs Rest (AUC = %0.2f)' % roc_auc[2])
plt.plot(fpr[3], tpr[3], linestyle='solid',color='black', label='D vs Rest (AUC = %0.2f)' % roc_auc[3])
plt.plot(fpr[4], tpr[4], linestyle='solid',color='red', label='E vs Rest (AUC = %0.2f)' % roc_auc[4])
plt.plot(p_fpr, p_tpr, linestyle='solid', color='blue')
plt.title('ROC curve for Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('ROC Random Forest',dpi=300);
plt.show()

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import metrics

clf = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=3))
clf.fit(X_train, y_train)

pred_prob = clf.predict_proba(X_test)

fpr = {}
tpr = {}
thresh ={}
roc_auc = {}

n_class = 5

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pred_prob[:,i], pos_label=i)
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

plt.figure(figsize=(12,8))
plt.plot(fpr[0], tpr[0], linestyle='solid',color='magenta', label='A vs Rest (AUC = %0.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1], linestyle='solid',color='green', label='B vs Rest (AUC = %0.2f)' % roc_auc[1])
plt.plot(fpr[2], tpr[2], linestyle='solid',color='orange', label='C Severe vs Rest (AUC = %0.2f)' % roc_auc[2])
plt.plot(fpr[3], tpr[3], linestyle='solid',color='black', label='D vs Rest (AUC = %0.2f)' % roc_auc[3])
plt.plot(fpr[4], tpr[4], linestyle='solid',color='red', label='E vs Rest (AUC = %0.2f)' % roc_auc[4])
plt.plot(p_fpr, p_tpr, linestyle='solid', color='blue')
plt.title('ROC curve for K Nearest Neighbour')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('ROC K Nearest Neighbour',dpi=300);
plt.show()

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import metrics

clf = OneVsRestClassifier(GaussianNB())
clf.fit(X_train, y_train)

pred_prob = clf.predict_proba(X_test)

fpr = {}
tpr = {}
thresh ={}
roc_auc = {}

n_class = 5

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pred_prob[:,i], pos_label=i)
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

plt.figure(figsize=(12,8))
plt.plot(fpr[0], tpr[0], linestyle='solid',color='magenta', label='A vs Rest (AUC = %0.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1], linestyle='solid',color='green', label='B vs Rest (AUC = %0.2f)' % roc_auc[1])
plt.plot(fpr[2], tpr[2], linestyle='solid',color='orange', label='C Severe vs Rest (AUC = %0.2f)' % roc_auc[2])
plt.plot(fpr[3], tpr[3], linestyle='solid',color='black', label='D vs Rest (AUC = %0.2f)' % roc_auc[3])
plt.plot(fpr[4], tpr[4], linestyle='solid',color='red', label='E vs Rest (AUC = %0.2f)' % roc_auc[4])
plt.plot(p_fpr, p_tpr, linestyle='solid', color='blue')
plt.title('ROC curve for Gaussian Bayes')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('ROC Gaussian Bayes',dpi=300);
plt.show()
